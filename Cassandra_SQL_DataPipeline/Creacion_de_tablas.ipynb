# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="162.241.60.182",
  user="leudadoc_henry",
  password="tenboj-dEckow-nokka8",
  database="leudadoc_Henry"
)

mycursor = mydb.cursor()

# %%
mycursor.execute("SHOW TABLES")

for table in mycursor:
  print(table)
# Out:
# ('Rest_google',)
# ('categorias',)
# ('clientes',)
# ('estados',)

# %%
#Tabla Estados
mycursor.execute("CREATE TABLE IF NOT EXISTS estados (stateID int AUTO_INCREMENT, state varchar(255), primary key (stateID))")

# %%
#Tabla Clientes
mycursor.execute("CREATE TABLE IF NOT EXISTS clientes (clientID int, name varchar(255), primary key (clientID))")

# %%
#Tabla Categoria
mycursor.execute("CREATE TABLE IF NOT EXISTS categorias (categoryID int AUTO_INCREMENT, category varchar(255), primary key (categoryID))")

# %%
#Tabla Local
mycursor.execute("CREATE TABLE IF NOT EXISTS locales (storeID int, name varchar(255), )")
create table restaurant (
gmapID int,
name varchar(255),
address varchar(255),
latitude decimal(9,6),
longitude decimal(9,6),
state varchar(255),
delivery varchar(255),
permanently_closed varchar(255)
);

# %%
#Tabla intermedia Categoria_Local
mycursor.execute("CREATE TABLE IF NOT EXISTS categoria_local (categoryID int not null, storeID int not null)")

# %%
#Tabla review
mycursor.execute("CREATE TABLE IF NOT EXISTS reviews (reviewID int AUTO_INCREMENT, clientID int not null, storeID int not null, date datetime, rating int, text varchar(255),primary key (reviewID), FOREIGN KEY (clientID) REFERENCES clientes(clientID), FOREIGN KEY (storeID) REFERENCES stores(storeID))")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     632                 query = query.encode("utf-8")
# --> 633             self._cmysql.query(
#     634                 query,
#
# MySQLInterfaceError: Cannot add foreign key constraint
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-52-cab8b4bd1632> in <cell line: 1>()
# ----> 1 mycursor.execute("CREATE TABLE IF NOT EXISTS review (reviewID int AUTO_INCREMENT, clientID int not null, storeID int not null, date datetime, rating int, text varchar(255),primary key (reviewID), FOREIGN KEY (clientID) REFERENCES clientes(clientID), FOREIGN KEY (storeID) REFERENCES stores(storeID))")
#
# ...

# %% [markdown]
# stateID INT, FOREIGN KEY (stateID) REFERENCES estado(stateID))")

# %%
mycursor.execute("CREATE TABLE IF NOT EXISTS review (reviewID int not null , clienteID int not null, gmapID int not null, date datetime, rating int, text varchar(255), primary key (reviewID) )")
# Out:
#   File "<ipython-input-11-2e3f1e18ab64>", line 3
#     create table review (
#            ^
# SyntaxError: invalid syntax
