# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import ast

# %% [markdown]
# ### Reviews YELP

# %%
file_path = './review_yelp.json'
# Specify the number of rows to read per batch (e.g., 250000 rows)
batch_size = 250000

# Create an empty list to store the loaded DataFrames
dfs = []

# Read the JSON file in batches using read_json with chunksize
for chunk in pd.read_json(file_path, lines=True, chunksize=batch_size):
    dfs.append(chunk)

# Concatenate the list of DataFrames into a single DataFrame
df = pd.concat(dfs, ignore_index=True)

# %%
df.head()
# Out:
#                 review_id                 user_id             business_id
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw  \
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool
# 0      3       0      0     0  \
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        int64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 480.0+ MB

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        int64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 480.0+ MB

# %%
# Comments

df['comment'] = ''
df.loc[(df['funny'] == 1), 'comment'] = 'Funny'
df.loc[(df['useful'] == 1), 'comment'] = 'Useful'
df.loc[(df['cool'] == 1), 'comment'] = 'Cool'
df.loc[(df['funny'] == 1) & (df['useful'] == 1), 'comment'] = 'Funny Useful'
df.loc[(df['funny'] == 1) & (df['cool'] == 1), 'comment'] = 'Funny Cool'
df.loc[(df['useful'] == 1) & (df['cool'] == 1), 'comment'] = 'Useful Cool'
df.loc[(df['funny'] == 1) & (df['useful'] == 1) & (df['cool'] == 1), 'comment'] = 'Funny Useful Cool'

# %%
df.head()
# Out:
#                 review_id                 user_id             business_id
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw  \
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool
# 0      3       0      0     0  \
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11  \
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
#
#        comment
# 0
# 1  Useful Cool
# 2
# 3  Useful Cool
# 4  Useful Cool

# %%
# Drop columns

columns_to_drop = ['useful','funny','cool']

df = df.drop(columns_to_drop, axis=1)

df.head()
# Out:
#                 review_id                 user_id             business_id
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw  \
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars                                               text
# 0      3  If you decide to eat here, just be aware it is...  \
# 1      5  I've taken a lot of spin classes over the year...
# 2      3  Family diner. Had the buffet. Eclectic assortm...
# 3      5  Wow!  Yummy, different,  delicious.   Our favo...
# 4      4  Cute interior and owner (?) gave us tour of up...
#
#                  date      comment
# 0 2018-07-07 22:09:11
# 1 2012-01-03 15:28:18  Useful Cool
# 2 2014-02-05 20:30:30
# 3 2015-01-04 00:01:03  Useful Cool
# 4 2017-01-14 20:54:15  Useful Cool

# %%
df = df.rename(columns={"stars": "rating"})
df.head()
# Out:
#                 review_id                 user_id             business_id
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw  \
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    rating                                               text
# 0       3  If you decide to eat here, just be aware it is...  \
# 1       5  I've taken a lot of spin classes over the year...
# 2       3  Family diner. Had the buffet. Eclectic assortm...
# 3       5  Wow!  Yummy, different,  delicious.   Our favo...
# 4       4  Cute interior and owner (?) gave us tour of up...
#
#                  date      comment
# 0 2018-07-07 22:09:11
# 1 2012-01-03 15:28:18  Useful Cool
# 2 2014-02-05 20:30:30
# 3 2015-01-04 00:01:03  Useful Cool
# 4 2017-01-14 20:54:15  Useful Cool

# %% [markdown]
# ### Business Table

# %%
# Read the pickle file using read_pickle
df_stores = pd.read_pickle('business.pkl')

# %%
df_stores.head()
# Out:
#               business_id                      name
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  \
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101  \
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN  \
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# 2  32.223236 -110.880452   3.5           22  ...   NaN         NaN      NaN
# 3  39.955505  -75.155564   4.0           80  ...   NaN         NaN      NaN
# 4  40.338183  -75.471659   4.5           13  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 1       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 2       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 3       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 4       NaN   NaN          NaN     NaN        NaN        NaN   NaN
#
# [5 rows x 28 columns]

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
#  17  city          5 non-null       object
#  18  state         5 non-null       object
#  19  postal_code   5 non-null       object
#  20  latitude      5 non-null       object
#  21  longitude     5 non-null       object
#  22  stars         5 non-null       object
#  23  review_count  5 non-null       object
#  24  is_open       5 non-null       object
#  25  attributes    5 non-null       object
#  26  categories    5 non-null       object
#  27  hours         5 non-null       object
# dtypes: object(28)
# memory usage: 33.3+ MB

# %%
# Assuming your DataFrame is named 'df'
df_stores = df_stores.iloc[:, :14]  # Select the first 15 columns using iloc

# %%
df_stores.head()
# Out:
#               business_id                      name
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  \
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101  \
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count is_open
# 0  34.426679 -119.711197   5.0            7       0  \
# 1  38.551126  -90.335695   3.0           15       1
# 2  32.223236 -110.880452   3.5           22       0
# 3  39.955505  -75.155564   4.0           80       1
# 4  40.338183  -75.471659   4.5           13       1
#
#                                           attributes
# 0                      {'ByAppointmentOnly': 'True'}  \
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories
# 0  Doctors, Traditional Chinese Medicine, Naturop...  \
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
# Filtering the States of interest
states = ['NV','TX','CA','FL','NY']

df_stores = df_stores[df_stores['state'].isin(states)]

# %%
df_stores.head()
# Out:
#                business_id                      name
# 3   MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries  \
# 10  UJsufbvfyfONHeWdvAHKjA                 Marshalls
# 13  jaxMSoInw8Poo3XeMJt8lQ              Adams Dental
# 14  0bPLkL0QhhPO5kt1_EXmNQ      Zio's Italian Market
# 16  rBmpy_Y1UbBx8ggHlyb7hA  Arizona Truck Outfitters
#
#                       address           city state postal_code   latitude
# 3                 935 Race St   Philadelphia    CA       19107  39.955505  \
# 10  21705 Village Lakes Sc Dr  Land O' Lakes    FL       34639  28.190459
# 13          15 N Missouri Ave     Clearwater    FL       33755  27.966235
# 14              2575 E Bay Dr          Largo    FL       33771  27.916116
# 16            625 N Stone Ave         Tucson    FL       85705  32.229872
#
#      longitude stars review_count is_open
# 3   -75.155564   4.0           80       1  \
# 10   -82.45738   3.5            6       1
# 13  -82.787412   5.0           10       1
# 14  -82.760461   4.5          100       0
# 16 -110.972342   4.5           10       1
#
#                                            attributes
# 3   {'RestaurantsDelivery': 'False', 'OutdoorSeati...  \
# 10  {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 13                      {'ByAppointmentOnly': 'True'}
# 14  {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# 16  {'DriveThru': 'False', 'BusinessAcceptsCreditC...
#
#                                            categories
# 3   Restaurants, Food, Bubble Tea, Coffee & Tea, B...  \
# 10               Department Stores, Shopping, Fashion
# 13  General Dentistry, Dentists, Health & Medical,...
# 14        Food, Delis, Italian, Bakeries, Restaurants
# 16  Automotive, Auto Parts & Supplies, Auto Custom...
#
#                                                 hours
# 3   {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 10  {'Monday': '9:30-21:30', 'Tuesday': '9:30-21:3...
# 13  {'Monday': '7:30-15:30', 'Tuesday': '7:30-15:3...
# 14  {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 16  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39228 entries, 3 to 150333
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   39228 non-null  object
#  1   name          39228 non-null  object
#  2   address       39228 non-null  object
#  3   city          39228 non-null  object
#  4   state         39228 non-null  object
#  5   postal_code   39228 non-null  object
#  6   latitude      39228 non-null  object
#  7   longitude     39228 non-null  object
#  8   stars         39228 non-null  object
#  9   review_count  39228 non-null  object
#  10  is_open       39228 non-null  object
#  11  attributes    35613 non-null  object
#  12  categories    39228 non-null  object
#  13  hours         33103 non-null  object
# dtypes: object(14)
# memory usage: 4.5+ MB

# %%
df_stores = df_stores.dropna(subset=['categories'])

# %%
# Define the list of gastronomic tags to filter on
gastronomic_tags = ['food', 'restaurant', 'cafe', 'bar', 'Restaurant', 'Bar','Food']  # replace with your actual list of tags


# Use a nested loop to check if any of the gastronomic tags are in the category list for each row
is_gastronomic = []

df_stores['categories'] = df_stores['categories'].apply(lambda x: x.replace(', ', ',').split(','))


for categories in df_stores['categories']:
    found_tag = False
    for tag in categories:
        if tag.lower() in gastronomic_tags:
            found_tag = True
            break
    is_gastronomic.append(found_tag)

# Filter the DataFrame based on this condition
df_stores_food = df_stores[is_gastronomic]

# %%
df_stores['categories'].iloc[1].replace(', ',',').split(',')
# Out:
# ['Department Stores', 'Shopping', 'Fashion']

# %%
df_stores_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7204 entries, 3 to 150321
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   7204 non-null   object
#  1   name          7204 non-null   object
#  2   address       7204 non-null   object
#  3   city          7204 non-null   object
#  4   state         7204 non-null   object
#  5   postal_code   7204 non-null   object
#  6   latitude      7204 non-null   object
#  7   longitude     7204 non-null   object
#  8   stars         7204 non-null   object
#  9   review_count  7204 non-null   object
#  10  is_open       7204 non-null   object
#  11  attributes    7097 non-null   object
#  12  categories    7204 non-null   object
#  13  hours         6258 non-null   object
# dtypes: object(14)
# memory usage: 844.2+ KB

# %%
df_stores_food.head()
# Out:
#                business_id                   name           address
# 3   MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries       935 Race St  \
# 14  0bPLkL0QhhPO5kt1_EXmNQ   Zio's Italian Market     2575 E Bay Dr
# 53  cVBxfMC4lp3DnocjYA3FHQ      Paws The Cat Cafe  10588 109 Street
# 82  ppFCk9aQkM338Rgwpl2F5A                   Wawa  3604 Chestnut St
# 88  LhpPSrulqVeTyJeK2xydvQ  Fresh Fruits & Salads      114 N 3rd St
#
#             city state postal_code   latitude  longitude stars review_count
# 3   Philadelphia    CA       19107  39.955505 -75.155564   4.0           80  \
# 14         Largo    FL       33771  27.916116 -82.760461   4.5          100
# 53      Edmonton    FL     T5H 3B2  53.549633 -113.50878   5.0           20
# 82  Philadelphia    FL       19104  39.954573 -75.194894   3.0           56
# 88        Camden    CA       08102   39.94669 -75.123327   4.5            6
#
#    is_open                                         attributes
# 3        1  {'RestaurantsDelivery': 'False', 'OutdoorSeati...  \
# 14       0  {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# 53       0  {'RestaurantsAttire': ''casual'', 'Restaurants...
# 82       1  {'Alcohol': 'u'none'', 'RestaurantsGoodForGrou...
# 88       1  {'BusinessParking': '{'garage': False, 'street...
#
#                                            categories
# 3   [Restaurants, Food, Bubble Tea, Coffee & Tea, ...  \
# 14      [Food, Delis, Italian, Bakeries, Restaurants]
# 53  [Coffee & Tea, Cafes, Pets, Restaurants, Pet A...
# 82  [Restaurants, Automotive, Delis, Gas Stations,...
# 88  [Juice Bars & Smoothies, Restaurants, Fruits &...
#
#                                                 hours
# 3   {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 14  {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 53  {'Monday': '0:0-0:0', 'Tuesday': '10:0-21:0', ...
# 82  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 88  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...

# %%
df_stores_food['address_complete'] = (
    df_stores_food['address'].astype(str) + ', ' +
    df_stores_food['city'].astype(str) + ', ' +
    df_stores_food['state'].astype(str) + ' ' +
    df_stores_food['postal_code'].astype(str)
)
# Out:
# C:\Users\Marco\AppData\Local\Temp\ipykernel_14108\700369656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stores_food['address_complete'] = (

# %%
df_stores_food
# Out:
#                    business_id                   name
# 3       MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries  \
# 14      0bPLkL0QhhPO5kt1_EXmNQ   Zio's Italian Market
# 53      cVBxfMC4lp3DnocjYA3FHQ      Paws The Cat Cafe
# 82      ppFCk9aQkM338Rgwpl2F5A                   Wawa
# 88      LhpPSrulqVeTyJeK2xydvQ  Fresh Fruits & Salads
# ...                        ...                    ...
# 150247  uakBDIQ5uDIG9QsVSv3aHA          King of Tarts
# 150283  Y5gyxnQt44B3axgzrjttlw     Don Cruz Snowballs
# 150293  0UqeZTDBdV0uY3wesbLvYQ                   ampm
# 150306  wVxXRFf10zTTAs11nr4xeA           PrimoHoagies
# 150321  AM7O0cwkxm6w_e0Q7-f9FQ              Starbucks
#
#                           address          city state postal_code   latitude
# 3                     935 Race St  Philadelphia    CA       19107  39.955505  \
# 14                  2575 E Bay Dr         Largo    FL       33771  27.916116
# 53               10588 109 Street      Edmonton    FL     T5H 3B2  53.549633
# 82               3604 Chestnut St  Philadelphia    FL       19104  39.954573
# 88                   114 N 3rd St        Camden    CA       08102   39.94669
# ...                           ...           ...   ...         ...        ...
# 150247  1414 E Old York Rd, Ste E    Warminster    FL       18974  40.228769
# 150283         4213 Williams Blvd        Kenner    FL       70065  30.033566
# 150293         1701 Victorian Ave        Sparks    CA       89431  39.534947
# 150306             6024 Ridge Ave  Philadelphia    CA       19128  40.032483
# 150321               8817 S US-31  Indianapolis    NV       46227  39.638245
#
#          longitude stars review_count is_open
# 3       -75.155564   4.0           80       1  \
# 14      -82.760461   4.5          100       0
# 53      -113.50878   5.0           20       0
# 82      -75.194894   3.0           56       1
# 88      -75.123327   4.5            6       1
# ...            ...   ...          ...     ...
# 150247  -75.094705   4.5           20       0
# 150283   -90.23852   4.5            6       1
# 150293 -119.765698   4.0            5       1
# 150306   -75.21443   3.0           55       1
# 150321  -86.128069   4.0           29       1
#
#                                                attributes
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...  \
# 14      {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# 53      {'RestaurantsAttire': ''casual'', 'Restaurants...
# 82      {'Alcohol': 'u'none'', 'RestaurantsGoodForGrou...
# 88      {'BusinessParking': '{'garage': False, 'street...
# ...                                                   ...
# 150247  {'RestaurantsPriceRange2': '3', 'BusinessAccep...
# 150283  {'RestaurantsTakeOut': 'True', 'DogsAllowed': ...
# 150293             {'BusinessAcceptsCreditCards': 'True'}
# 150306  {'NoiseLevel': 'u'average'', 'RestaurantsTakeO...
# 150321  {'RestaurantsPriceRange2': '1', 'Caters': 'Fal...
#
#                                                categories
# 3       [Restaurants, Food, Bubble Tea, Coffee & Tea, ...  \
# 14          [Food, Delis, Italian, Bakeries, Restaurants]
# 53      [Coffee & Tea, Cafes, Pets, Restaurants, Pet A...
# 82      [Restaurants, Automotive, Delis, Gas Stations,...
# 88      [Juice Bars & Smoothies, Restaurants, Fruits &...
# ...                                                   ...
# 150247                         [Bakeries, Desserts, Food]
# 150283  [Mexican, Shaved Ice, Restaurants, Food, Food ...
# 150293  [Convenience Stores, Food, Automotive, Gas Sta...
# 150306  [Restaurants, Specialty Food, Food, Sandwiches...
# 150321                               [Food, Coffee & Tea]
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  \
# 14      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 53      {'Monday': '0:0-0:0', 'Tuesday': '10:0-21:0', ...
# 82      {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 88      {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
# ...                                                   ...
# 150247  {'Tuesday': '8:0-15:0', 'Wednesday': '8:0-15:0...
# 150283  {'Monday': '14:0-21:0', 'Tuesday': '14:0-21:0'...
# 150293  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150306  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 150321  {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...
#
#                                        address_complete
# 3                   935 Race St, Philadelphia, CA 19107
# 14                       2575 E Bay Dr, Largo, FL 33771
# 53               10588 109 Street, Edmonton, FL T5H 3B2
# 82             3604 Chestnut St, Philadelphia, FL 19104
# 88                       114 N 3rd St, Camden, CA 08102
# ...                                                 ...
# 150247  1414 E Old York Rd, Ste E, Warminster, FL 18974
# 150283             4213 Williams Blvd, Kenner, FL 70065
# 150293             1701 Victorian Ave, Sparks, CA 89431
# 150306           6024 Ridge Ave, Philadelphia, CA 19128
# 150321             8817 S US-31, Indianapolis, NV 46227
#
# [7204 rows x 15 columns]

# %%
# Drop columns

columns_to_drop = ['address','city','postal_code','is_open']

df_stores_food = df_stores_food.drop(columns_to_drop, axis=1)

df_stores_food.head()
# Out:
#                business_id                   name state   latitude  longitude
# 3   MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries    CA  39.955505 -75.155564  \
# 14  0bPLkL0QhhPO5kt1_EXmNQ   Zio's Italian Market    FL  27.916116 -82.760461
# 53  cVBxfMC4lp3DnocjYA3FHQ      Paws The Cat Cafe    FL  53.549633 -113.50878
# 82  ppFCk9aQkM338Rgwpl2F5A                   Wawa    FL  39.954573 -75.194894
# 88  LhpPSrulqVeTyJeK2xydvQ  Fresh Fruits & Salads    CA   39.94669 -75.123327
#
#    stars review_count                                         attributes
# 3    4.0           80  {'RestaurantsDelivery': 'False', 'OutdoorSeati...  \
# 14   4.5          100  {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# 53   5.0           20  {'RestaurantsAttire': ''casual'', 'Restaurants...
# 82   3.0           56  {'Alcohol': 'u'none'', 'RestaurantsGoodForGrou...
# 88   4.5            6  {'BusinessParking': '{'garage': False, 'street...
#
#                                            categories
# 3   [Restaurants, Food, Bubble Tea, Coffee & Tea, ...  \
# 14      [Food, Delis, Italian, Bakeries, Restaurants]
# 53  [Coffee & Tea, Cafes, Pets, Restaurants, Pet A...
# 82  [Restaurants, Automotive, Delis, Gas Stations,...
# 88  [Juice Bars & Smoothies, Restaurants, Fruits &...
#
#                                                 hours
# 3   {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...  \
# 14  {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 53  {'Monday': '0:0-0:0', 'Tuesday': '10:0-21:0', ...
# 82  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 88  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
#
#                             address_complete
# 3        935 Race St, Philadelphia, CA 19107
# 14            2575 E Bay Dr, Largo, FL 33771
# 53    10588 109 Street, Edmonton, FL T5H 3B2
# 82  3604 Chestnut St, Philadelphia, FL 19104
# 88            114 N 3rd St, Camden, CA 08102

# %% [markdown]
# ### Formating Yelp API responses

# %% [markdown]
# Mi idea seria ir consultando a Cassandra o MySQL para ir barriendo la tabla de locales y, asi, ir actualizando sus reviews.
#
# Por ejemplo, si puedo hacer 400 consultas diarias. Tomar 40 locales y traer las 10 reviews mas nuevas. Luego al dia siguiente traer los siguientes 40 locales.
#
# PD Aca uso un ejemplo del Json que devuelve YelpAPI para no gastar creditos.

# %%
import json

# Specify the path to your JSON file
example_file = './review_example.json'


# Load the JSON file into a dictionary
with open(example_file, 'r') as file:
    response = json.load(file)

reviews = response['reviews']

# %%
reviews
# Out:
# [{'id': 'zY1hO4VhjYj6ApRk3FOywA',
#   'rating': 5,
#   'text': "This place has such unique flavors and they were all pretty good. My sis and I couldn't decide on just like 1-2 flavors so we ended up getting like 5...",
#   'time_created': '2023-08-07 16:17:57',
#   'url': 'https://www.yelp.com/biz/merry-monarch-creamery-austin?adjust_creative=9XlpwIp1qnfNvM0eFgnFHw&hrid=zY1hO4VhjYj6ApRk3FOywA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=9XlpwIp1qnfNvM0eFgnFHw',
#   'user': {'id': 'xQqXx9jGf-YtGg43-BBndA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/0OF2rVmME_B62WXLBGCs_g/o.jpg',
#    'name': 'Dolly N.',
#    'profile_url': 'https://www.yelp.com/user_details?userid=xQqXx9jGf-YtGg43-BBndA'}},
#  {'id': 'gUsoPKPYqpwDpcZj_91EgQ',
#   'rating': 5,
#   'text': 'This place was wonderful. Came here after eating at another truck in the lot for dinner. \n The gal that helped us let me try two different types of ice...',
#   'time_created': '2023-08-03 18:40:56',
#   'url': 'https://www.yelp.com/biz/merry-monarch-creamery-austin?adjust_creative=9XlpwIp1qnfNvM0eFgnFHw&hrid=gUsoPKPYqpwDpcZj_91EgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=9XlpwIp1qnfNvM0eFgnFHw',
#   'user': {'id': '324wpRmJv5zXNSqEjRR4rQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/qwg_2T3BJ_FzD_uSbo2n6w/o.jpg',
#    'name': 'Mary B.',
#    'profile_url': 'https://www.yelp.com/user_details?userid=324wpRmJv5zXNSqEjRR4rQ'}},
#  {'id': 'IcE46kt0n_UTKSWY5vBdqw',
#   'rating': 5,
#   'text': 'The Oreo miso lives up to the hype. A super creamy base with just the right amount of chocolate cookie and truffle pieces plus a perfectly balanced...',
#   'time_created': '2023-08-03 17:34:22',
#   'url': 'https://www.yelp.com/biz/merry-monarch-creamery-austin?adjust_creative=9XlpwIp1qnfNvM0eFgnFHw&hrid=IcE46kt0n_UTKSWY5vBdqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=9XlpwIp1qnfNvM0eFgnFHw',
#   'user': {'id': 'GZeRcprW27wmkIDZBeP74A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/m4xxTPrSIF5hulrd75Slcw/o.jpg',
#    'name': 'Sarah P.',
#    'profile_url': 'https://www.yelp.com/user_details?userid=GZeRcprW27wmkIDZBeP74A'}}]

# %%
dictionary = {'review_id' : [],
              'user_id': [],
              'business_name': [],
              'business_id':[],
              'Platform':[],
              'rating':[],
              'date': [],
              'text':[],
              'comment':[],
}

for review in reviews:
    dictionary['review_id'].append(review['id'])
    dictionary['user_id'].append(review['user']['id'])
    dictionary['business_name'].append('I have to get it from the request')
    dictionary['business_id'].append('I have to get it from the request')
    dictionary['date'].append(review['time_created'])
    dictionary['Platform'].append('Yelp')
    dictionary['rating'].append(review['rating'])
    dictionary['text'].append(review['text'])
    dictionary['comment'].append('')


df_yelp_api = pd.DataFrame(dictionary)

# %%
df_yelp_api.head()
# Out:
#                 review_id                 user_id
# 0  zY1hO4VhjYj6ApRk3FOywA  xQqXx9jGf-YtGg43-BBndA  \
# 1  gUsoPKPYqpwDpcZj_91EgQ  324wpRmJv5zXNSqEjRR4rQ
# 2  IcE46kt0n_UTKSWY5vBdqw  GZeRcprW27wmkIDZBeP74A
#
#                        business_name                        business_id
# 0  I have to get it from the request  I have to get it from the request  \
# 1  I have to get it from the request  I have to get it from the request
# 2  I have to get it from the request  I have to get it from the request
#
#   Platform  rating                 date
# 0     Yelp       5  2023-08-07 16:17:57  \
# 1     Yelp       5  2023-08-03 18:40:56
# 2     Yelp       5  2023-08-03 17:34:22
#
#                                                 text comment
# 0  This place has such unique flavors and they we...
# 1  This place was wonderful. Came here after eati...
# 2  The Oreo miso lives up to the hype. A super cr...
