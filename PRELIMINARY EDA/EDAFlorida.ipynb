# %% [markdown]
# ## EDA Florida State
#
# In this script, we are going to focus on understanding trends in the Gastronomic shops located in the state of Florida.
# In particular, it will be of interest to identify:
#
# + Most frequent Gastronomic shops
# + Categories with higher number of reviews (then, probably higher number of customers)
# + Categories with higher and lower Average Rating scores
# + Categories with higher percentage of Perpetualy closed state.

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import ast

# %% [markdown]
# ### Load Florida-Reviews

# %%
folder_path = './review-Florida/'
dfmerge = pd.DataFrame()

for file_name in os.listdir(folder_path):
    if file_name.endswith('.json'):
        file_path = os.path.join(folder_path, file_name)
        dfaux = pd.read_json(file_path, lines=True)
        dfmerge = pd.concat([dfmerge, dfaux], ignore_index=True)
# Out:
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\carna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)

# %%
dfmerge.head()
# Out:
#         user_id              name           time  rating  \
# 0  1.014719e+20   Julie A. Gerber  1628003250740       1
# 1  1.154772e+20  Martin Sheffield  1595031217005       5
# 2  1.018050e+20      Brian Truett  1522924253567       5
# 3  1.063444e+20          Tina Sun  1467907819586       1
# 4  1.008751e+20      James Haynes  1480683415081       5
#
#                                                 text  pics  \
# 0  Update: Their “reply” to my review amounted to...  None
# 1  He's a knowledgeable doctor but the way he run...  None
# 2  Best doctor I've ever had, I never wait to be ...  None
# 3  I was told he is a good doctor. I was trying t...  None
# 4  Takes the time to actually get to know his pat...  None
#
#                                                 resp  \
# 0  {'time': 1627042799532, 'text': 'Thank you for...
# 1  {'time': 1582464056733, 'text': 'Thank you for...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                  gmap_id
# 0  0x8893863ea87bd5dd:0x9383ebf973e74abb
# 1  0x8893863ea87bd5dd:0x9383ebf973e74abb
# 2  0x8893863ea87bd5dd:0x9383ebf973e74abb
# 3  0x8893863ea87bd5dd:0x9383ebf973e74abb
# 4  0x8893863ea87bd5dd:0x9383ebf973e74abb

# %%
# Get the gmaps_ids of all unique shops in the dataset
Florida_gmap_id = dfmerge['gmap_id'].unique()
Florida_gmap_id
# Out:
# array(['0x8893863ea87bd5dd:0x9383ebf973e74abb',
#        '0x88c33f1c8e1f99a3:0x99b22c5bd258b3a7',
#        '0x88c33c2935058dd3:0xb888c702ecf5aef6', ...,
#        '0x88d903a5a1ec65a1:0x9e44682bff7be2c7',
#        '0x88d9b297e990ba8f:0x814c58a8c0123622',
#        '0x88c313d4ed64b857:0x2bc265e33c753434'], dtype=object)

# %%
# Get the number of total unique shops in Florida
len(Florida_gmap_id)
# Out:
# 59200

# %% [markdown]
# ### Load Metadata-Sitios

# %%
folder_path = './metadata-sitios/'
dfmeta = pd.DataFrame()

for file_name in os.listdir(folder_path):
    if file_name.endswith('.json'):
        file_path = os.path.join(folder_path, file_name)
        dfaux = pd.read_json(file_path, lines=True)
        dfmeta = pd.concat([dfmeta, dfaux], ignore_index=True)

# %%
dfmeta.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 1   [Textile exporter]         4.5               6  None
# 2  [Korean restaurant]         4.4              18  None
# 3       [Fabric store]         3.3               6  None
# 4       [Fabric store]         4.3               7  None
#
#                                                hours  \
# 0  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1                                               None
# 2  [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 3  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
#
#                                                 MISC              state  \
# 0  {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 1                                               None           Open now
# 2  {'Service options': ['Takeout', 'Dine-in', 'De...  Open ⋅ Closes 6PM
# 3  {'Service options': ['In-store shopping'], 'Pa...  Open ⋅ Closes 5PM
# 4           {'Service options': ['In-store pickup']}  Open ⋅ Closes 5PM
#
#                                     relative_results  \
# 0  [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1  [0x80c2c624136ea88b:0xb0315367ed448771, 0x80c2...
# 2  [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 3  [0x80c2c8811477253f:0x23a8a492df1918f7, 0x80c2...
# 4  [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Filter the DataFrame based on Florida's ids
df_filtered = dfmeta[dfmeta['gmap_id'].isin(Florida_gmap_id)]

df_filtered.head()
# Out:
#                            name  \
# 105           Brian Shaheen, MD
# 117                Mail Station
# 118              APC Pediatrics
# 119          Infinia Accounting
# 120  Baker Distributing Company
#
#                                                address  \
# 105  Brian Shaheen, MD, 2421 Thomas Dr, Panama City...
# 117  Mail Station, 8466 Lockwood Ridge Rd, Sarasota...
# 118  APC Pediatrics, 5255 Office Park Blvd 110 & 11...
# 119  Infinia Accounting, 555 W. Granada Blvd Ste Bl...
# 120  Baker Distributing Company, 7810 25th Ct E #11...
#
#                                    gmap_id description   latitude  longitude  \
# 105  0x8893863ea87bd5dd:0x9383ebf973e74abb        None  30.159982 -85.752277
# 117  0x88c33f1c8e1f99a3:0x99b22c5bd258b3a7        None  27.389683 -82.508387
# 118  0x88c33c2935058dd3:0xb888c702ecf5aef6        None  27.448302 -82.510850
# 119  0x88d908b8c02dc3bb:0xea94b1fb47b68ef6        None  29.280410 -81.071481
# 120  0x88c33fb303dc8e69:0x3485e731f1a704f8        None  27.401269 -82.532346
#
#                                               category  avg_rating  \
# 105  [Family practice physician, General practitioner]         4.2
# 117  [Mailing service, Courier service, Fax service...         3.4
# 118        [Pediatrician, Children's hospital, Doctor]         4.2
# 119  [Tax preparation service, Accountant, Payroll ...         5.0
# 120  [Air conditioning system supplier, Air filter ...         4.3
#
#      num_of_reviews price                                              hours  \
# 105              18  None  [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 117              28  None  [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 118              34  None  [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 119              13  None  [[Thursday, 10AM–5PM], [Friday, 10AM–4PM], [Sa...
# 120               8  None  [[Thursday, 7:30AM–5PM], [Friday, 7:30AM–5PM],...
#
#                                                   MISC              state  \
# 105  {'Service options': ['Online care'], 'Accessib...  Open ⋅ Closes 5PM
# 117  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 5PM
# 118  {'Service options': ['Online care'], 'Health &...  Open ⋅ Closes 5PM
# 119  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 5PM
# 120  {'Accessibility': ['Wheelchair accessible entr...  Open ⋅ Closes 5PM
#
#                                       relative_results  \
# 105  [0x88938ebfbd53f9c5:0xf6e52004f37523c8, 0x8893...
# 117  [0x88c3475a64b98c03:0xe8de19a19dae1b2c, 0x88c3...
# 118  [0x88c33e113c201abb:0x49ef8b29737f8773, 0x88c3...
# 119  [0x88e6dc9fd184eed9:0x81252448cc728aa8, 0x88e6...
# 120  [0x88c33e46cf5434ad:0x8772f525f32cc2d2, 0x88c3...
#
#                                                    url
# 105  https://www.google.com/maps/place//data=!4m2!3...
# 117  https://www.google.com/maps/place//data=!4m2!3...
# 118  https://www.google.com/maps/place//data=!4m2!3...
# 119  https://www.google.com/maps/place//data=!4m2!3...
# 120  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# #### Analyze Nan values in the columns of interest

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60032 entries, 105 to 2743117
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              60032 non-null  object
#  1   address           58984 non-null  object
#  2   gmap_id           60032 non-null  object
#  3   description       7436 non-null   object
#  4   latitude          60032 non-null  float64
#  5   longitude         60032 non-null  float64
#  6   category          59999 non-null  object
#  7   avg_rating        60032 non-null  float64
#  8   num_of_reviews    60032 non-null  int64
#  9   price             7072 non-null   object
#  10  hours             52303 non-null  object
#  11  MISC              53543 non-null  object
#  12  state             52863 non-null  object
#  13  relative_results  56716 non-null  object
#  14  url               60032 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 7.3+ MB

# %%
# As there are few shops without tags, they are going to be dropped
df_filtered = df_filtered.dropna(subset=['category'])

# %% [markdown]
# #### Filter Gastronomic associated Shops

# %%
# Define the list of gastronomic tags to filter on
gastronomic_tags = ['food', 'restaurant', 'cafe', 'bar', 'pub', 'bakery']  # replace with your actual list of tags


# Use a nested loop to check if any of the gastronomic tags are in the category list for each row
is_gastronomic = []
for categories in df_filtered['category']:
    found_tag = False
    for tag in categories:
        if tag.lower() in gastronomic_tags:
            found_tag = True
            break
    is_gastronomic.append(found_tag)

# Filter the DataFrame based on this condition
dfFlorida_gastronomic = df_filtered[is_gastronomic]

dfFlorida_gastronomic.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 # Use a nested loop to check if any of the gastronomic tags are in the category list for each row
#       6 is_gastronomic = []
# ----> 7 for categories in df_filtered['category']:
#       8     found_tag = False
#       9     for tag in categories:
#
# NameError: name 'df_filtered' is not defined

# %%
dfFlorida_gastronomic.to_csv('Florida_gastronimic_df.csv')

# %%
dfFlorida_gastronomic = pd.read_csv('./Florida_gastronimic_df.csv')

dfFlorida_gastronomic = dfFlorida_gastronomic.drop('Unnamed: 0', axis=1)
# Use the apply() method to convert the category column to a list of strings
dfFlorida_gastronomic['category'] = dfFlorida_gastronomic['category'].apply(lambda x: ast.literal_eval(x))

dfFlorida_gastronomic.head()
# Out:
#                                                 name  \
# 0                                    Oneyda's Bakery
# 1                         Daily Dose Craft Bar, Inc.
# 2  Gormley's on the river | Modern cuisine in his...
# 3                                       Bachata Rosa
# 4                                  Zampini's Bottega
#
#                                              address  \
# 0  Oneyda's Bakery, 600 Goodlette-Frank Rd #101, ...
# 1  Daily Dose Craft Bar, Inc., 11643 Beach Blvd U...
# 2  Gormley's on the river | Modern cuisine in his...
# 3    Bachata Rosa, 887w W 29th St, Hialeah, FL 33012
# 4  Zampini's Bottega, 510 SE 5th Ave, Fort Lauder...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x88dae191ee505917:0x6ba3e25388d3fad4         NaN  26.154754 -81.790528
# 1  0x88e5b53b107a2609:0x40106d3b48960d9d         NaN  30.287836 -81.517501
# 2  0x8894b5a7a7909725:0xe4687299fd288188         NaN  29.726949 -84.981535
# 3  0x88d9ba5d65937567:0xbc27649cf513cc89         NaN  25.848173 -80.299773
# 4   0x88d900575f0dd065:0x9b3638d2a80be4d         NaN  26.116549 -80.138561
#
#                                       category  avg_rating  num_of_reviews  \
# 0                           ['Bakery', 'Deli']         4.6              19
# 1  ['Coffee shop', 'Bubble tea store', 'Cafe']         5.0              27
# 2   ['Modern French restaurant', 'Restaurant']         4.3              17
# 3                               ['Restaurant']         3.6               8
# 4                               ['Restaurant']         4.7              18
#
#   price                                              hours  \
# 0     $  [['Thursday', '8AM–6PM'], ['Friday', '8AM–6PM'...
# 1   NaN  [['Thursday', '10AM–8PM'], ['Friday', '10AM–8P...
# 2   NaN  [['Thursday', '5–9PM'], ['Friday', '5–10PM'], ...
# 3   NaN  [['Thursday', '6PM–1AM'], ['Friday', '6PM–1AM'...
# 4   NaN  [['Thursday', '8:30AM–10PM'], ['Friday', '7AM–...
#
#                                                 MISC                state  \
# 0                  {'Service options': ['Delivery']}   Permanently closed
# 1  {'From the business': ['Identifies as women-le...  Closed ⋅ Opens 10AM
# 2                  {'Service options': ['Delivery']}   Permanently closed
# 3  {'Service options': ['Dine-in', 'Delivery'], '...   Closed ⋅ Opens 6PM
# 4  {'Service options': ['Outdoor seating', 'Takeo...   Permanently closed
#
#                                     relative_results  \
# 0  ['0x88dae1997e122d6b:0xfd776fa851f06d29', '0x8...
# 1                                                NaN
# 2  ['0x8894b5a649e1f5cb:0xe5ef826dc2f3842f', '0x8...
# 3  ['0x88d9b07ccb3270b9:0x844f5431085b8f88', '0x8...
# 4                                                NaN
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# First, create a list of all the gastronomic tags in the df_gastronomic DataFrame
all_tags = []
for categories in dfFlorida_gastronomic['category']:
    categories = [x.lower() for x in categories]
    all_tags.extend(categories)
unique_tags = set(all_tags)

# Then, count the number of times each unique tag appears in the df_gastronomic DataFrame
tag_counts = {}
for tag in unique_tags:
    count = all_tags.count(tag)
    tag_counts[tag] = count

# Sort the tags and their counts in descending order of count
sorted_tags = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

# Finally, print the sorted list of unique tags and their counts
for tag, count in sorted_tags:
    print(tag, count)
# Out:
# restaurant 2468
# bar 652
# fast food restaurant 525
# bakery 464
# sandwich shop 435
# cafe 405
# takeout restaurant 401
# breakfast restaurant 335
# coffee shop 330
# caterer 281
# american restaurant 276
# hamburger restaurant 208
# seafood restaurant 167
# bar & grill 128
# pizza restaurant 112
# italian restaurant 105
# family restaurant 101
# mexican restaurant 88
# deli 84
# lounge 77
# bagel shop 76
# steak house 74
# sports bar 74
# lunch restaurant 73
# juice shop 73
# convenience store 72
# cocktail bar 69
# grocery store 65
# delivery restaurant 65
# gas station 64
# donut shop 63
# espresso bar 61
# night club 60
# wine bar 59
# vegetarian restaurant 59
# supermarket 58
# brunch restaurant 58
# vegan restaurant 55
# latin american restaurant 54
# coffee store 54
# salad shop 54
# cake shop 53
# chicken restaurant 52
# health food restaurant 51
# florist 51
# atm 50
# chinese restaurant 48
# dessert shop 48
# pub 48
# event venue 47
# ice cream shop 47
# beer store 46
# barbecue restaurant 45
# wine store 43
# sushi restaurant 43
# chicken wings restaurant 41
# diner 41
# taco restaurant 40
# asian restaurant 40
# tex-mex restaurant 37
# seafood market 35
# dessert restaurant 35
# gluten-free restaurant 35
# burrito restaurant 33
# pizza delivery 33
# pastry shop 33
# live music venue 32
# internet cafe 31
# cheesesteak restaurant 29
# southern restaurant (us) 29
# candy store 29
# japanese restaurant 26
# mediterranean restaurant 26
# cajun restaurant 26
# fine dining restaurant 25
# cuban restaurant 25
# caribbean restaurant 25
# adult entertainment club 25
# wedding bakery 24
# hoagie restaurant 24
# pizza takeout 24
# cafeteria 22
# health food store 19
# spanish restaurant 18
# pretzel store 18
# pasta shop 18
# cookie shop 18
# colombian restaurant 18
# cupcake shop 17
# delivery service 17
# hot dog restaurant 17
# gift shop 16
# european restaurant 16
# organic restaurant 16
# catering food and drink supplier 16
# peruvian restaurant 16
# new american restaurant 16
# tea house 16
# hookah bar 15
# greek restaurant 15
# alternative fuel station 14
# soup restaurant 14
# live music bar 13
# car wash 13
# kosher restaurant 13
# wholesale bakery 13
# gastropub 13
# pool hall 13
# jamaican restaurant 13
# electric vehicle charging station 12
# traditional american restaurant 12
# soul food restaurant 12
# indian restaurant 12
# banquet hall 11
# french restaurant 11
# video arcade 11
# asian fusion restaurant 11
# cigar shop 11
# haitian restaurant 10
# thai restaurant 10
# bistro 10
# tapas restaurant 10
# tobacco shop 10
# grill 10
# wedding venue 10
# meal delivery 10
# brewpub 10
# soup shop 10
# hobby store 9
# crab house 9
# beer garden 9
# brewery 9
# liquor store 9
# brazilian restaurant 9
# karaoke bar 9
# argentinian restaurant 8
# oyster bar restaurant 8
# pizza takeaway 8
# buffet restaurant 8
# karaoke 8
# southwestern restaurant (us) 8
# bubble tea store 8
# venezuelan restaurant 8
# shopping mall 8
# irish pub 8
# club 7
# coffee roasters 7
# middle eastern restaurant 7
# tourist attraction 7
# fried chicken takeaway 7
# tapas bar 7
# pancake restaurant 7
# eclectic restaurant 6
# californian restaurant 6
# frozen yogurt shop 6
# store 6
# hookah store 6
# australian restaurant 6
# market 6
# puerto rican restaurant 6
# golf course 6
# south american restaurant 6
# beer hall 6
# japanese steakhouse 6
# produce market 6
# children's party service 5
# chocolate shop 5
# small plates restaurant 5
# hot dog stand 5
# pool billard club 5
# comedy club 5
# art gallery 4
# dance club 4
# chinese takeaway 4
# food court 4
# toy store 4
# korean restaurant 4
# amusement center 4
# honduran restaurant 4
# country club 4
# butcher shop 4
# snack bar 4
# piano bar 4
# kiosk 4
# mexican grocery store 4
# bbq area 3
# pet groomer 3
# laser tag center 3
# fish & chips restaurant 3
# beauty salon 3
# box lunch supplier 3
# turkish restaurant 3
# farmers' market 3
# book store 3
# south asian restaurant 3
# vitamin & supplements store 3
# fruits wholesaler 3
# nuevo latino restaurant 3
# creole restaurant 3
# bowling alley 3
# pet supply store 3
# party planner 3
# angler fish restaurant 3
# hawaiian restaurant 3
# association or organization 3
# dart bar 3
# halal restaurant 3
# chicken shop 3
# service establishment 3
# dominican restaurant 3
# teppanyaki restaurant 3
# hair salon 3
# delivery chinese restaurant 3
# childrens book store 3
# wholesaler 3
# nutritionist 3
# açaí shop 3
# vegetarian cafe and deli 3
# golf club 3
# golf driving range 3
# event planner 3
# boutique 3
# food 3
# pan-latin restaurant 3
# hair extension technician 2
# discount supermarket 2
# men's clothing store 2
# movie theater 2
# gay bar 2
# tour operator 2
# fruit and vegetable store 2
# barber shop 2
# mexican torta restaurant 2
# floridian restaurant 2
# fusion restaurant 2
# nicaraguan restaurant 2
# pakistani restaurant 2
# golf instructor 2
# sweets and dessert buffet 2
# discount store 2
# sports club 2
# frozen dessert supplier 2
# parking garage 2
# lebanese restaurant 2
# down home cooking restaurant 2
# clothing store 2
# coworking space 2
# tennis club 2
# marina 2
# mongolian barbecue restaurant 2
# museum 2
# tamale shop 2
# vaporizer store 2
# dinner theater 2
# farm 2
# make-up artist 2
# chinese bakery 2
# irish restaurant 2
# indian takeaway 2
# board game club 2
# porridge restaurant 2
# meat products 2
# ethnic restaurant 2
# musical club 2
# entertainment 2
# modern indian restaurant 2
# spa 2
# distillery 2
# bait shop 2
# tennis court 2
# pan-asian restaurant 2
# chinese tea house 2
# herbalist 2
# cruise line company 2
# hairdresser 2
# kosher grocery store 2
# meat dish restaurant 2
# catering 2
# grill store 2
# winery 2
# spice store 2
# central american restaurant 2
# cabaret club 2
# department store 2
# health consultant 2
# recreation center 2
# gym 2
# public golf course 2
# theme park 2
# rice restaurant 2
# bingo hall 2
# soft drinks shop 2
# social club 2
# concert hall 2
# swimming pool 2
# vietnamese restaurant 2
# modern french restaurant 2
# wi-fi spot 2
# food products supplier 2
# bicycle rental service 2
# indoor playground 2
# coffee stand 2
# yacht club 2
# gyro restaurant 2
# authentic japanese restaurant 2
# gourmet grocery store 2
# health and beauty shop 1
# souvenir store 1
# drive-in movie theater 1
# falafel restaurant 1
# organic farm 1
# antique store 1
# water sports equipment rental service 1
# food producer 1
# salvadoran restaurant 1
# historical landmark 1
# british restaurant 1
# stadium 1
# game store 1
# boat tour agency 1
# laotian restaurant 1
# uzbeki restaurant 1
# southeast asian restaurant 1
# cruise agency 1
# animals 1
# cabin rental agency 1
# baking supply store 1
# stand bar 1
# comic book store 1
# cooking class 1
# dance restaurant 1
# cider bar 1
# sushi takeaway 1
# crêperie 1
# charcuterie 1
# pharmacy 1
# skin care clinic 1
# tiki bar 1
# chilean restaurant 1
# bicycle repair shop 1
# boat club 1
# beauty supply store 1
# pet sitter 1
# veterans organization 1
# beverages 1
# stylist 1
# hot pot restaurant 1
# israeli restaurant 1
# brewing supply store 1
# recreation 1
# korean barbecue restaurant 1
# indonesian restaurant 1
# dog walker 1
# meat processor 1
# sake brewery 1
# park 1
# modern european restaurant 1
# costume jewelry shop 1
# post office 1
# aromatherapy supply store 1
# grocery delivery service 1
# canoe & kayak rental service 1
# seafood 1
# pet adoption service 1
# children's amusement center 1
# cars 1
# record store 1
# housing development 1
# beach volleyball court 1
# modern british restaurant 1
# cottage rental 1
# stage 1
# chophouse restaurant 1
# cold storage facility 1
# wellness center 1
# swim club 1
# retirement community 1
# bicycle shop 1
# shipping and mailing service 1
# waxing hair removal service 1
# russian restaurant 1
# cantonese restaurant 1
# raw food restaurant 1
# bowling club 1
# business center 1
# propane supplier 1
# beauty product supplier 1
# fondue restaurant 1
# money order service 1
# fishing charter 1
# dog trainer 1
# gay night club 1
# japanese cheap sweets shop 1
# pet store 1
# boat cover supplier 1
# rock climbing 1
# georgian restaurant 1
# housing association 1
# wine club 1
# money transfer service 1
# southern italian restaurant 1
# continental restaurant 1
# organic food store 1
# corporate entertainment service 1
# tattoo shop 1
# used furniture store 1
# market operator 1
# wholesale food store 1
# dance hall 1
# fishing store 1
# office space rental agency 1
# home goods store 1
# gift basket store 1
# fresh food market 1
# lottery retailer 1
# hotel supply store 1
# traditional restaurant 1
# art school 1
# helicopter tour agency 1
# nail salon 1
# tea store 1
# fishing camp 1
# rock climbing gym 1
# marine supply store 1
# massage spa 1
# izakaya restaurant 1
# chinese noodle restaurant 1
# beer distributor 1
# fitness center 1
# natural goods store 1
# spa and health club 1
# swedish restaurant 1
# motel 1
# food and drink 1
# scandinavian restaurant 1
# children's clothing store 1
# german restaurant 1
# eyebrow bar 1
# doctor 1
# mobile caterer 1
# sports nutrition store 1
# fruit parlor 1
# pier 1
# wedding store 1
# ice skating rink 1
# shawarma restaurant 1
# miniature golf course 1
# wedding planner 1
# after school program 1
# self-catering accommodation 1
# karaoke equipment rental service 1
# weight loss service 1
# boat rental service 1
# dj service 1
# uruguayan restaurant 1
# performing arts group 1
# golf course builder 1
# bouncy castle hire 1
# upholstery shop 1
# honey farm 1
# transportation infrastructure 1
# health spa 1
# punjabi restaurant 1
# women's clothing store 1
# new england restaurant 1
# coffee wholesaler 1
# amusement park 1
# botanical garden 1
# candle store 1
# interior designer 1
# lingerie store 1
# check cashing service 1
# amusement park ride 1
# day spa 1
# biryani restaurant 1
# butcher shop deli 1
# jazz club 1
# adult entertainment store 1
# basketball court 1
# non-profit organization 1

# %%
# Top 30 most frequent categories
Florida_Top30_gastronomic = sorted_tags[:30]

# Finally, generate a bar plot of the top 30 tags
tags = [tag for tag, count in Florida_Top30_gastronomic]
counts = [count for tag, count in Florida_Top30_gastronomic]
fig, ax = plt.subplots()
ax.bar(tags, counts)
ax.set_title('Top 30 Gastronomic Tags')
ax.set_xlabel('Tag')
ax.set_ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It can be appreaciated that there are some big categories like:
#
# + Restaurant
# + Bar
# + Fast Food restaurant
# + Cafe
# + Bakery
#
# But there are also more specific categories leading such as:
# + Sandwhich Shop
# + Breakfast restaurant
# + Takeout Restaurant
# + Pizza restaurant
# + Seafood restaurant
# + International food ( American, Italian, Mexican)

# %%
import numpy as np

# First, create a dictionary to store the average rating score and number of reviews for each tag
tag_stats = {}
for tag in unique_tags:
    tag_stats[tag] = {'rating_sum': 0, 'num_reviews': 0}

# Then, iterate over the rows in the df_gastronomic DataFrame and update the counters for each tag
for index, row in dfFlorida_gastronomic.iterrows():
    categories = row['category']
    rating = row['avg_rating']
    num_reviews = row['num_of_reviews']
    for tag in categories:

        tag_stats[tag.lower()]['rating_sum'] += rating
        tag_stats[tag.lower()]['num_reviews'] += num_reviews

# Finally, calculate the average rating score and average number of reviews for each tag
for tag in tag_stats:
    tag = tag.lower()
    count = all_tags.count(tag)
    avg_rating = tag_stats[tag]['rating_sum'] / tag_stats[tag]['num_reviews']
    avg_reviews = tag_stats[tag]['num_reviews'] / count
    print(tag, avg_rating, avg_reviews)
# Out:
# hair extension technician 0.04409090909090909 110.0
# club 0.04429012345679013 92.57142857142857
# health and beauty shop 0.10638297872340426 47.0
# discount supermarket 0.002116806937005866 1960.5
# souvenir store 0.16428571428571428 28.0
# men's clothing store 0.015870307167235496 293.0
# movie theater 0.13548387096774195 31.0
# eclectic restaurant 0.003923555812943391 1151.1666666666667
# gay bar 0.10000000000000002 45.5
# tour operator 0.08828828828828829 55.5
# argentinian restaurant 0.04156142365097589 108.875
# drive-in movie theater 0.192 25.0
# seafood market 0.010397794407246948 435.25714285714287
# children's party service 0.03277693474962064 131.8
# falafel restaurant 0.07758620689655173 58.0
# californian restaurant 0.00406352171882298 1070.5
# art gallery 0.09230769230769233 52.0
# fruit and vegetable store 0.04381443298969072 97.0
# bar & grill 0.006217986896962475 655.859375
# organic farm 0.09375 48.0
# antique store 0.0793103448275862 58.0
# chinese restaurant 0.00990375826657347 387.4791666666667
# water sports equipment rental service 0.006104651162790698 688.0
# barber shop 0.09895833333333333 48.0
# food producer 0.12894736842105264 38.0
# mexican torta restaurant 0.016926070038910505 257.0
# haitian restaurant 0.06771523178807946 60.4
# oyster bar restaurant 0.002744760713168595 1598.5
# salvadoran restaurant 0.009450549450549451 455.0
# lunch restaurant 0.010194680743754413 407.4109589041096
# historical landmark 0.015436241610738253 298.0
# british restaurant 0.0640625 64.0
# stadium 0.012716763005780347 346.0
# game store 0.052873563218390804 87.0
# boat tour agency 0.057692307692307696 78.0
# laotian restaurant 0.09583333333333333 48.0
# night club 0.01795915291280429 221.15
# floridian restaurant 0.01220196353436185 356.5
# health food restaurant 0.029100257069408733 152.54901960784315
# uzbeki restaurant 0.06206896551724138 58.0
# southeast asian restaurant 0.10285714285714286 35.0
# coffee roasters 0.09969604863221884 47.0
# bbq area 0.09583333333333334 48.0
# cruise agency 0.057692307692307696 78.0
# pizza restaurant 0.015043962768527163 277.2232142857143
# animals 0.32857142857142857 14.0
# pet groomer 0.08322981366459627 53.666666666666664
# cabin rental agency 0.060810810810810814 74.0
# baking supply store 0.02634730538922156 167.0
# restaurant 0.012826951505407913 325.6223662884927
# fusion restaurant 0.03953488372093023 107.5
# stand bar 0.0018556701030927835 2425.0
# laser tag center 0.012039532794249777 371.0
# fish & chips restaurant 0.06596858638743455 63.666666666666664
# comic book store 0.052873563218390804 87.0
# electric vehicle charging station 0.08394833948339483 45.166666666666664
# nicaraguan restaurant 0.008449304174950299 503.0
# hobby store 0.001723764563211919 2565.4444444444443
# cooking class 0.041525423728813564 118.0
# wedding bakery 0.054097536450477636 82.875
# pakistani restaurant 0.015514018691588787 267.5
# dance restaurant 0.005296343001261034 793.0
# frozen yogurt shop 0.0924187725631769 46.166666666666664
# chicken wings restaurant 0.004760181499317988 876.170731707317
# crab house 0.0051591195850273375 792.5555555555555
# dessert shop 0.030188149396237023 148.375
# cider bar 0.17500000000000002 28.0
# dance club 0.011302549965541005 362.75
# chinese takeaway 0.025396825396825397 157.5
# sushi takeaway 0.014765100671140941 298.0
# crêperie 0.06363636363636364 66.0
# golf instructor 0.03362068965517241 116.0
# atm 0.02598962598962599 146.52
# spanish restaurant 0.007287968441814596 563.3333333333334
# charcuterie 0.2777777777777778 18.0
# hoagie restaurant 0.058835208471211126 62.958333333333336
# japanese restaurant 0.010825958702064898 391.15384615384613
# banquet hall 0.008383473726434013 453.27272727272725
# sweets and dessert buffet 0.0734375 64.0
# pharmacy 0.07543859649122807 57.0
# wine bar 0.009340600619856792 475.77966101694915
# dessert restaurant 0.007030607583371403 625.4285714285714
# traditional american restaurant 0.004314247669773634 938.75
# beauty salon 0.052158273381294966 92.66666666666667
# discount store 0.002116806937005866 1960.5
# skin care clinic 0.045283018867924525 106.0
# tiki bar 0.0180672268907563 238.0
# beer garden 0.03276561232765613 137.0
# chilean restaurant 0.05057471264367817 87.0
# box lunch supplier 0.05638766519823789 75.66666666666667
# sports club 0.06267605633802817 71.0
# pretzel store 0.10956521739130434 31.944444444444443
# brewery 0.009841656516443363 456.1111111111111
# soul food restaurant 0.014133333333333333 312.5
# bicycle repair shop 0.09375 48.0
# boat club 0.15 28.0
# chocolate shop 0.05776699029126213 82.4
# wine store 0.013753863444787861 331.06976744186045
# frozen dessert supplier 0.14821428571428572 28.0
# store 0.10717131474103585 41.833333333333336
# beauty supply store 0.04298245614035088 114.0
# pizza takeaway 0.008498513379583746 504.5
# grocery store 0.007068930868167201 612.4307692307692
# pet sitter 0.10652173913043479 46.0
# veterans organization 0.12432432432432432 37.0
# parking garage 0.625 8.0
# deli 0.009376488646588686 449.8333333333333
# beverages 0.10444444444444445 45.0
# turkish restaurant 0.025276752767527673 180.66666666666666
# farmers' market 0.015096359743040686 311.3333333333333
# stylist 0.045283018867924525 106.0
# lebanese restaurant 0.13 35.0
# hot pot restaurant 0.09375 48.0
# israeli restaurant 0.032167832167832165 143.0
# brewing supply store 0.009161793372319689 513.0
# gift shop 0.00275110710506721 1594.8125
# book store 0.0029111772205694855 1568.6666666666667
# down home cooking restaurant 0.003272870662460568 1268.0
# supermarket 0.006288523444713396 690.9137931034483
# clothing store 0.0028125 1600.0
# coworking space 0.12054794520547946 36.5
# tennis club 0.0808695652173913 57.5
# fine dining restaurant 0.00930416447021613 455.28
# marina 0.08285714285714285 52.5
# mongolian barbecue restaurant 0.0031976744186046516 1376.0
# recreation 0.196 25.0
# chicken restaurant 0.005279910129189292 718.9807692307693
# liquor store 0.0228735632183908 193.33333333333334
# korean barbecue restaurant 0.10217391304347827 46.0
# european restaurant 0.005516029863855951 711.5625
# thai restaurant 0.027664974619289337 157.6
# indonesian restaurant 0.08363636363636363 55.0
# south asian restaurant 0.004634146341463415 956.6666666666666
# dog walker 0.10652173913043479 46.0
# alternative fuel station 0.08141732283464567 45.357142857142854
# meat processor 0.1 44.0
# museum 0.004900376952073237 928.5
# sake brewery 0.11842105263157894 38.0
# hookah store 0.022811244979919678 207.5
# tamale shop 0.01673076923076923 260.0
# park 0.0034220532319391636 1315.0
# cuban restaurant 0.005532818732839456 772.12
# modern european restaurant 0.12142857142857143 28.0
# costume jewelry shop 0.0793103448275862 58.0
# vitamin & supplements store 0.07833333333333334 60.0
# post office 0.10571428571428572 35.0
# cheesesteak restaurant 0.06302895322939868 61.93103448275862
# aromatherapy supply store 0.09166666666666667 48.0
# brazilian restaurant 0.008178286648947045 543.4444444444445
# breakfast restaurant 0.006093389584290578 643.1731343283582
# vaporizer store 0.01760154738878143 258.5
# mediterranean restaurant 0.01378437047756874 318.9230769230769
# fruits wholesaler 0.05433070866141733 84.66666666666667
# dinner theater 0.625 8.0
# buffet restaurant 0.0019589949504167426 2054.625
# farm 0.010616438356164385 438.0
# grocery delivery service 0.059259259259259255 81.0
# canoe & kayak rental service 0.07894736842105263 57.0
# make-up artist 0.04409090909090909 110.0
# juice shop 0.049984197218710474 86.68493150684931
# seafood 0.07547169811320754 53.0
# pet adoption service 0.059259259259259255 81.0
# middle eastern restaurant 0.012981574539363484 341.14285714285717
# small plates restaurant 0.007245451643791894 626.6
# event venue 0.009184870915327676 471.40425531914894
# children's amusement center 0.05058823529411764 85.0
# southern restaurant (us) 0.003245245610831399 1321.8275862068965
# live music bar 0.011310234966148944 386.3076923076923
# chinese bakery 0.14098360655737707 30.5
# karaoke bar 0.025544959128065394 163.11111111111111
# irish restaurant 0.008478038815117467 489.5
# nuevo latino restaurant 0.00595446584938704 761.3333333333334
# indian takeaway 0.01355421686746988 332.0
# board game club 0.09417475728155339 51.5
# cars 0.20555555555555557 18.0
# record store 0.09074074074074075 54.0
# housing development 0.04017857142857143 112.0
# organic restaurant 0.023929299796057107 183.875
# creole restaurant 0.007457428068115092 567.6666666666666
# bowling alley 0.01264367816091954 348.0
# beach volleyball court 0.005333333333333333 750.0
# modern british restaurant 0.15357142857142855 28.0
# cottage rental 0.060810810810810814 74.0
# cocktail bar 0.01030636685375183 405.40579710144925
# stage 0.1392857142857143 28.0
# chophouse restaurant 0.0017404464623533861 2643.0
# soup restaurant 0.01580411797440178 256.7142857142857
# caribbean restaurant 0.012121559633027525 348.8
# beer store 0.013377305327868851 339.4782608695652
# family restaurant 0.005094070835584809 806.2178217821782
# bagel shop 0.022284587378640773 173.47368421052633
# cold storage facility 0.10222222222222221 45.0
# wellness center 0.10638297872340426 47.0
# porridge restaurant 0.013149350649350649 308.0
# swim club 0.16428571428571428 28.0
# karaoke 0.012513924990716675 336.625
# pet supply store 0.06855670103092784 64.66666666666667
# burrito restaurant 0.006915908223881411 556.030303030303
# bistro 0.03448553054662379 124.4
# car wash 0.10995260663507109 32.46153846153846
# retirement community 0.04017857142857143 112.0
# pub 0.011274238227146816 376.0416666666667
# espresso bar 0.01634341695902562 247.65573770491804
# bicycle shop 0.09375 48.0
# shipping and mailing service 0.15 28.0
# party planner 0.002021891152325935 2192.6666666666665
# fast food restaurant 0.00870982787144919 432.8990476190476
# waxing hair removal service 0.045283018867924525 106.0
# angler fish restaurant 0.0032240873967492676 1251.0
# meat products 0.0361344537815126 119.0
# caterer 0.02034037580117963 194.8861209964413
# russian restaurant 0.06206896551724138 58.0
# kosher restaurant 0.03046218487394958 146.46153846153845
# hawaiian restaurant 0.10230769230769231 43.333333333333336
# cantonese restaurant 0.0064469914040114614 698.0
# takeout restaurant 0.011167653392655352 350.8753117206983
# raw food restaurant 0.030612244897959183 147.0
# bowling club 0.004633620689655172 928.0
# ethnic restaurant 0.013149350649350649 308.0
# food court 0.044411764705882345 85.0
# tapas restaurant 0.013787536325476269 309.7
# health food store 0.06322344322344323 71.84210526315789
# cake shop 0.0318661971830986 139.32075471698113
# business center 0.15 28.0
# toy store 0.003865652724968314 1183.5
# pasta shop 0.03380695737383635 113.38888888888889
# pizza delivery 0.02528486163863266 167.54545454545453
# wholesale bakery 0.09335548172757475 46.30769230769231
# delivery restaurant 0.03136379654645836 130.96923076923076
# propane supplier 0.07543859649122807 57.0
# beauty product supplier 0.04298245614035088 114.0
# catering food and drink supplier 0.01587338262476895 270.5
# musical club 0.07164179104477612 67.0
# fondue restaurant 0.004994324631101022 881.0
# association or organization 0.24259259259259258 18.0
# australian restaurant 0.002532031726662599 1639.0
# money order service 0.07543859649122807 57.0
# diner 0.005443974630021142 784.4878048780488
# korean restaurant 0.01846473029045643 241.0
# southwestern restaurant (us) 0.011262203626220364 358.5
# fishing charter 0.1484848484848485 33.0
# dog trainer 0.10652173913043479 46.0
# coffee shop 0.008983446721255822 446.3090909090909
# gay night club 0.07636363636363637 55.0
# japanese cheap sweets shop 0.13333333333333333 33.0
# entertainment 0.00834990059642147 503.0
# dart bar 0.0665024630541872 67.66666666666667
# pet store 0.06307692307692307 65.0
# modern indian restaurant 0.009528688524590165 488.0
# spa 0.09895833333333333 48.0
# boat cover supplier 0.08275862068965517 58.0
# florist 0.006401753272968451 679.9607843137255
# rock climbing 0.040170940170940174 117.0
# halal restaurant 0.008122157244964262 513.0
# hot dog stand 0.020127504553734063 219.6
# french restaurant 0.015063694267515925 285.45454545454544
# distillery 0.1 47.0
# georgian restaurant 0.06206896551724138 58.0
# bait shop 0.08785046728971962 53.5
# housing association 0.04017857142857143 112.0
# wine club 0.04897959183673469 98.0
# cafeteria 0.01593049691458266 279.90909090909093
# money transfer service 0.07543859649122807 57.0
# southern italian restaurant 0.006181318681318681 728.0
# continental restaurant 0.07241379310344828 58.0
# cafe 0.02555508641148465 169.58765432098767
# sandwich shop 0.01079303600874334 359.68275862068964
# tourist attraction 0.021093247588424437 222.14285714285714
# tennis court 0.065 70.0
# pan-asian restaurant 0.0031976744186046516 1376.0
# amusement center 0.008951533135509398 505.5
# chinese tea house 0.07190082644628099 60.5
# herbalist 0.059756097560975614 82.0
# cruise line company 0.06025641025641026 78.0
# hairdresser 0.04409090909090909 110.0
# chicken shop 0.019724770642201836 218.0
# market 0.003880718954248366 1224.0
# organic food store 0.05529411764705883 85.0
# puerto rican restaurant 0.003232897969740075 1288.8333333333333
# corporate entertainment service 0.06470588235294118 68.0
# tattoo shop 0.07758620689655173 58.0
# kosher grocery store 0.2041666666666667 24.0
# vegan restaurant 0.014563106796116512 309.0
# meat dish restaurant 0.006049822064056939 702.5
# fried chicken takeaway 0.06967592592592593 61.714285714285715
# catering 0.05692307692307692 65.0
# honduran restaurant 0.041161616161616156 99.0
# used furniture store 0.0793103448275862 58.0
# market operator 0.008811475409836065 488.0
# cookie shop 0.016656410256410258 270.8333333333333
# steak house 0.003941582914572863 1032.6486486486488
# hamburger restaurant 0.0039051124010133042 964.0961538461538
# service establishment 0.18873239436619718 23.666666666666668
# wholesale food store 0.11142857142857143 35.0
# dance hall 0.08750000000000001 48.0
# fishing store 0.060810810810810814 74.0
# pool billard club 0.07547169811320754 53.0
# office space rental agency 0.10222222222222221 45.0
# cupcake shop 0.06223662884927068 72.58823529411765
# video arcade 0.01073170731707317 410.0
# tobacco shop 0.04720638540478906 87.7
# home goods store 0.04 120.0
# dominican restaurant 0.002472324723247232 1806.6666666666667
# gift basket store 0.12894736842105264 38.0
# teppanyaki restaurant 0.005017779533781114 843.6666666666666
# convenience store 0.08365746549560853 44.27777777777778
# gastropub 0.009650750801417246 455.9230769230769
# fresh food market 0.03220338983050847 118.0
# lottery retailer 0.07543859649122807 57.0
# hotel supply store 0.11142857142857143 35.0
# grill store 0.045454545454545456 88.0
# brunch restaurant 0.006615404665710934 661.4655172413793
# winery 0.55 8.0
# grill 0.009199318568994889 469.6
# latin american restaurant 0.0055680945063388415 771.2592592592592
# taco restaurant 0.007165671434522982 540.075
# hair salon 0.052158273381294966 92.66666666666667
# peruvian restaurant 0.004836224797374238 933.0625
# traditional restaurant 0.03310344827586207 145.0
# art school 0.11764705882352941 34.0
# helicopter tour agency 0.0793103448275862 58.0
# spice store 0.009967141292442496 456.5
# nail salon 0.041666666666666664 108.0
# tea store 0.10638297872340426 47.0
# central american restaurant 0.009129967776584319 465.5
# cabaret club 0.043455497382198956 95.5
# fishing camp 0.060810810810810814 74.0
# rock climbing gym 0.02017167381974249 233.0
# department store 0.002116806937005866 1960.5
# health consultant 0.09894736842105263 47.5
# marine supply store 0.16071428571428573 28.0
# tex-mex restaurant 0.004682985153940683 813.7567567567568
# wedding venue 0.006758620689655171 652.5
# delivery chinese restaurant 0.01983050847457627 196.66666666666666
# recreation center 0.0210161662817552 216.5
# live music venue 0.0056518765839333835 776.84375
# massage spa 0.16428571428571428 28.0
# gym 0.06413793103448276 72.5
# colombian restaurant 0.019994886218358474 217.27777777777777
# childrens book store 0.0029111772205694855 1568.6666666666667
# izakaya restaurant 0.07413793103448275 58.0
# chinese noodle restaurant 0.026404494382022473 178.0
# public golf course 0.03362068965517241 116.0
# comedy club 0.02623318385650224 178.4
# new american restaurant 0.010392921415716858 416.75
# beer distributor 0.010352422907488987 454.0
# theme park 0.625 8.0
# fitness center 0.16428571428571428 28.0
# natural goods store 0.04 120.0
# rice restaurant 0.020334261838440112 179.5
# spa and health club 0.044230769230769226 104.0
# bubble tea store 0.08263736263736264 56.875
# swedish restaurant 0.005912596401028277 778.0
# country club 0.06975806451612904 62.0
# bingo hall 0.043349753694581286 101.5
# delivery service 0.011822405782137328 341.8235294117647
# motel 0.060810810810810814 74.0
# cajun restaurant 0.004299928926794599 865.8461538461538
# soft drinks shop 0.09789473684210527 47.5
# asian restaurant 0.009573454068866914 419.65
# food and drink 0.11621621621621621 37.0
# meal delivery 0.010176030865686038 414.7
# social club 0.06597222222222222 72.0
# asian fusion restaurant 0.01339310731297282 324.45454545454544
# hookah bar 0.03282369804108934 139.53333333333333
# scandinavian restaurant 0.12142857142857143 28.0
# wholesaler 0.020268256333830104 223.66666666666666
# children's clothing store 0.14545454545454545 33.0
# butcher shop 0.030825688073394496 136.25
# german restaurant 0.018604651162790697 258.0
# eyebrow bar 0.045283018867924525 106.0
# concert hall 0.006448839208942391 581.5
# nutritionist 0.11056910569105691 41.0
# doctor 0.0851063829787234 47.0
# mobile caterer 0.06764705882352941 68.0
# snack bar 0.03463203463203463 115.5
# ice cream shop 0.009873170731707317 436.17021276595744
# coffee store 0.014951521230357742 276.94444444444446
# brewpub 0.003050707709220833 1455.4
# sports nutrition store 0.09166666666666667 48.0
# donut shop 0.02104808024904877 183.55555555555554
# gas station 0.0831354748603352 44.75
# mexican restaurant 0.005986450280721514 665.8977272727273
# tea house 0.019666490206458442 236.125
# fruit parlor 0.08750000000000001 48.0
# american restaurant 0.004192934722498727 982.7608695652174
# lounge 0.020504284569385366 210.66233766233765
# pier 0.2222222222222222 18.0
# venezuelan restaurant 0.015602517985611512 278.0
# wedding store 0.06764705882352941 68.0
# bakery 0.02110595277122703 203.79525862068965
# golf course 0.0271617497456765 163.83333333333334
# shopping mall 0.043312883435582816 101.875
# tapas bar 0.01492985971943888 285.14285714285717
# ice skating rink 0.05058823529411764 85.0
# piano bar 0.00523543990086741 807.0
# shawarma restaurant 0.007794361525704809 603.0
# swimming pool 0.056874999999999995 80.0
# açaí shop 0.0875 53.333333333333336
# vegetarian cafe and deli 0.06965174129353234 67.0
# miniature golf course 0.07708333333333334 48.0
# internet cafe 0.009391242435030261 453.06451612903226
# wedding planner 0.04886363636363636 88.0
# barbecue restaurant 0.006659884460269594 611.6222222222223
# after school program 0.02017167381974249 233.0
# vietnamese restaurant 0.014710743801652893 302.5
# self-catering accommodation 0.10222222222222221 45.0
# modern french restaurant 0.2529411764705882 17.0
# karaoke equipment rental service 0.29411764705882354 17.0
# golf club 0.017638483965014575 228.66666666666666
# hot dog restaurant 0.010589773387565367 404.94117647058823
# golf driving range 0.016057441253263707 255.33333333333334
# weight loss service 0.013315217391304349 368.0
# bar 0.01081890554954397 396.87116564417175
# boat rental service 0.060810810810810814 74.0
# seafood restaurant 0.004216625970334197 985.8323353293413
# pizza takeout 0.06502271252433486 64.20833333333333
# dj service 0.03523809523809524 105.0
# event planner 0.040955631399317405 97.66666666666667
# gluten-free restaurant 0.005078242300890863 856.3142857142857
# vegetarian restaurant 0.010552438498057837 392.7118644067797
# wi-fi spot 0.04272300469483568 106.5
# sushi restaurant 0.008846980186201956 487.09302325581393
# soup shop 0.03169864960909736 140.7
# greek restaurant 0.012248767538869927 351.6
# uruguayan restaurant 0.034722222222222224 144.0
# performing arts group 0.17500000000000002 24.0
# golf course builder 0.09583333333333333 48.0
# indian restaurant 0.01610062893081761 265.0
# food products supplier 0.1450980392156863 25.5
# bicycle rental service 0.08571428571428572 52.5
# south american restaurant 0.0021469926021228693 2072.6666666666665
# indoor playground 0.026857142857142857 175.0
# bouncy castle hire 0.02364864864864865 148.0
# upholstery shop 0.16071428571428573 28.0
# honey farm 0.09375 48.0
# transportation infrastructure 0.20555555555555557 18.0
# health spa 0.044230769230769226 104.0
# punjabi restaurant 0.009409190371991246 457.0
# women's clothing store 0.008522727272727272 528.0
# new england restaurant 0.06323529411764706 68.0
# coffee stand 0.12658227848101267 39.5
# coffee wholesaler 0.08448275862068966 58.0
# amusement park 0.05058823529411764 85.0
# pastry shop 0.04336861768368618 97.33333333333333
# botanical garden 0.0034220532319391636 1315.0
# salad shop 0.023826558265582654 170.83333333333334
# pool hall 0.021700654097729893 199.92307692307693
# candle store 0.09166666666666667 48.0
# interior designer 0.0793103448275862 58.0
# lingerie store 0.009719222462203024 463.0
# check cashing service 0.07543859649122807 57.0
# pancake restaurant 0.005513475427162233 811.0
# yacht club 0.0773913043478261 57.5
# amusement park ride 0.05058823529411764 85.0
# irish pub 0.008857574232511324 496.75
# day spa 0.08275862068965517 58.0
# biryani restaurant 0.009409190371991246 457.0
# beer hall 0.032109004739336484 140.66666666666666
# boutique 0.145 33.333333333333336
# food 0.18857142857142856 23.333333333333332
# butcher shop deli 0.005306603773584905 848.0
# jamaican restaurant 0.017144600366076877 252.15384615384616
# adult entertainment club 0.04206103494029191 90.44
# japanese steakhouse 0.006929133858267716 635.0
# cigar shop 0.0829581993569132 56.54545454545455
# produce market 0.002725864739287558 1614.1666666666667
# pan-latin restaurant 0.027644230769230768 138.66666666666666
# gyro restaurant 0.026265822784810128 158.0
# italian restaurant 0.01345283193199668 309.22857142857146
# jazz club 0.1131578947368421 38.0
# kiosk 0.05966101694915254 73.75
# mexican grocery store 0.022786458333333332 192.0
# adult entertainment store 0.009719222462203024 463.0
# sports bar 0.005572550031327166 733.3243243243244
# authentic japanese restaurant 0.007439446366782008 578.0
# basketball court 0.040170940170940174 117.0
# candy store 0.05739219712525668 67.17241379310344
# gourmet grocery store 0.009819413092550789 443.0
# non-profit organization 0.0793103448275862 58.0

# %% [markdown]
# #### Categories with  higher and lower number of reviews

# %%
# First, calculate the average rating score and average number of reviews for each tag
for tag in tag_stats:
    tag = tag.lower()
    count = all_tags.count(tag)
    if count > 0:
        tag_stats[tag]['avg_rating'] = tag_stats[tag]['rating_sum'] / count
        tag_stats[tag]['avg_reviews'] = tag_stats[tag]['num_reviews'] / count
    else:
        tag_stats[tag]['avg_rating'] = np.nan
        tag_stats[tag]['avg_reviews'] = np.nan

# Sort the tags by average number of reviews and get the top 30
sorted_tags_by_reviews = sorted(tag_stats.items(), key=lambda x: x[1]['avg_reviews'], reverse=True)[:30]

# Generate a bar plot of the top 30 tags sorted by average number of reviews
tags_by_reviews = [tag for tag, stats in sorted_tags_by_reviews]
avg_reviews_by_tag = [stats['avg_reviews'] for tag, stats in sorted_tags_by_reviews]
fig, ax = plt.subplots()
ax.bar(tags_by_reviews, avg_reviews_by_tag)
ax.set_title('Top 30 Tags by Average Number of Reviews')
ax.set_xlabel('Tag')
ax.set_ylabel('Average Number of Reviews')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It must be highlighted the high number or reviews that international restaurant get:
#
# + South american
# + Dominican
# + Australian
# + Mongolian
# + Pan-Asian
# + Puerto Rico

# %%
# Sort the tags by average number of reviews and get the top 30
sorted_tags_by_reviews = sorted(tag_stats.items(), key=lambda x: x[1]['avg_reviews'], reverse=False)[:30]

# Generate a bar plot of the top 30 tags sorted by average number of reviews
tags_by_reviews = [tag for tag, stats in sorted_tags_by_reviews]
avg_reviews_by_tag = [stats['avg_reviews'] for tag, stats in sorted_tags_by_reviews]
fig, ax = plt.subplots()
ax.bar(tags_by_reviews, avg_reviews_by_tag)
ax.set_title('Top 30 Tags with Lower Number of Reviews')
ax.set_xlabel('Tag')
ax.set_ylabel('Average Number of Reviews')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# On the other hand, it can be seen that places with shows do not attract people:
#
# + Dinner theaters
# + Karaoke bars
# + Performing art spaces
# + Recreation spaces
# + Driven-in movie theaters
#
# Additionally, european food is not of interest:
#
# + French restaurants
# + British restaurants
# + Scandinavian restaurants
# + European restaurants
# +

# %% [markdown]
# #### Categories with higher and lower scores

# %%
# Sort the tags by average rating score and get the top 30
sorted_tags_by_rating = sorted(tag_stats.items(), key=lambda x: x[1]['avg_rating'], reverse=True)[:30]

# Generate a bar plot of the top 30 tags sorted by average rating score
tags_by_rating = [tag for tag, stats in sorted_tags_by_rating]
avg_rating_by_tag = [stats['avg_rating'] for tag, stats in sorted_tags_by_rating]
fig, ax = plt.subplots()
ax.bar(tags_by_rating, avg_rating_by_tag)
ax.set_title('Top 30 Tags by Average Rating Score')
ax.set_xlabel('Tag')
ax.set_ylabel('Average Rating Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Surprisingly, many of the categories with lower number of reviews appear in the list of categories with higer scores, such as:
#
# + Dinner theater
# + Theme park
# + Karaoke bars
# + Board club bar
#
# So, it's highly likely that those categories have a reduced but faithful group of costumers.
#
#
# Some other popular categories are related to training and a healthy lifestyle.

# %%
# Sort the tags by average rating score and get the top 30
sorted_tags_by_rating = sorted(tag_stats.items(), key=lambda x: x[1]['avg_rating'], reverse=False)[:30]

# Generate a bar plot of the top 30 tags sorted by average rating score
tags_by_rating = [tag for tag, stats in sorted_tags_by_rating]
avg_rating_by_tag = [stats['avg_rating'] for tag, stats in sorted_tags_by_rating]
fig, ax = plt.subplots()
ax.bar(tags_by_rating, avg_rating_by_tag)
ax.set_title('Top 30 Tags by Worst Average Rating Score')
ax.set_xlabel('Tag')
ax.set_ylabel('Average Rating Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# However, aligned with another observation, *European food restaurants* have few and upset costumers.
#
# But, Sandwich restaurants have a high number of costumers, however, in average those shops do not have high rating scores. So, that may indicate that people find them useful but they are not always satisfied by the provided service.

# %% [markdown]
# #### Perpetualy Close categories

# %%
# First, create a dictionary to store the number of rows with each tag and the state 'Permanently closed'
tag_closed_counts = {}
for tag in unique_tags:
    tag_closed_counts[tag] = 0

# Then, iterate over the rows in the df_gastronomic DataFrame and update the counters for each tag with the state 'Permanently closed'
for index, row in dfFlorida_gastronomic.iterrows():
    categories = row['category']
    state = row['state']
    if state == 'Permanently closed':
        for tag in categories:
            tag_closed_counts[tag] += 1


# Normalize with the total number of shops
for tag in tag_stats:
    count = all_tags.count(tag)
    tag_closed_counts[tag] = tag_closed_counts[tag] / count *100


# Finally, sort the tags by the number of rows with the state 'Permanently closed' and get the top 5
sorted_closed_tags = sorted(tag_closed_counts.items(), key=lambda x: x[1], reverse=True)[:15]


# Print the top 5 tags with the highest number of rows with the state 'Permanently closed'
for tag, count in sorted_closed_tags:
    print(tag, count)
# Out:
# Karaoke equipment rental service 100.0
# Continental restaurant 100.0
# Costume jewelry shop 100.0
# DJ service 100.0
# Israeli restaurant 100.0
# Dance hall 100.0
# Fruit parlor 100.0
# Antique store 100.0
# Art school 100.0
# Bouncy castle hire 100.0
# Modern French restaurant 100.0
# Pet adoption service 100.0
# Pet store 100.0
# Modern British restaurant 100.0
# Event planner 100.0

# %% [markdown]
# From the above list, some trends are reinforced:
#
# + Places with entertaiment are appreciated by their loyal costumers but there are only a few of them, so those shops are not profitable
# + European Food is not popular in Florida.

# %%
# Finally, sort the tags by the number of rows with the state 'Permanently closed' and get the top 5
sorted_closed_tags = sorted(tag_closed_counts.items(), key=lambda x: x[1], reverse=False)[:15]


# Print the top 5 tags with the highest number of rows with the state 'Permanently closed'
for tag, count in sorted_closed_tags:
    print(tag, count)
# Out:
# Tennis club 0.0
# Water sports equipment rental service 0.0
# Biryani restaurant 0.0
# Bingo hall 0.0
# Chophouse restaurant 0.0
# Spa 0.0
# Charcuterie 0.0
# Bowling club 0.0
# Organic farm 0.0
# Golf driving range 0.0
# Mexican torta restaurant 0.0
# Miniature golf course 0.0
# Ice skating rink 0.0
# Marine supply store 0.0
# Wedding store 0.0
